# %%
import pandas as pd
from datetime import datetime as dt

# %%
wildfire_data = pd.read_csv("Resources/mapdataall.csv")

# %%
wildfire_df = pd.DataFrame(wildfire_data)
wildfire_df.head()
# Out:
#    incident_name incident_is_final incident_date_last_update  \
# 0    Bridge Fire                 Y      2018-01-09T13:46:00Z
# 1      Pala Fire                 Y      2020-09-16T14:07:35Z
# 2     River Fire                 Y      2022-10-24T11:39:23Z
# 3  Fawnskin Fire                 Y      2013-04-22T09:00:00Z
# 4      Gold Fire                 Y      2013-05-01T07:00:00Z
#
#   incident_date_created          incident_administrative_unit  \
# 0  2017-10-31T11:22:00Z       Shasta-Trinity National Forest
# 1  2009-05-24T14:56:00Z               CAL FIRE San Diego Unit
# 2  2013-02-24T08:16:00Z          CAL FIRE San Bernardino Unit
# 3  2013-04-20T17:30:00Z        San Bernardino National Forest
# 4  2013-04-30T12:59:00Z  CAL FIRE Madera-Mariposa-Merced Unit
#
#    incident_administrative_unit_url incident_county  \
# 0                               NaN          Shasta
# 1                               NaN       San Diego
# 2                               NaN            Inyo
# 3                               NaN  San Bernardino
# 4                               NaN          Madera
#
#                                    incident_location  incident_acres_burned  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake                    37.0
# 1        Hwy 76 and Pala Temecula, northwest of Pala                  122.0
# 2  south of Narrow Gauge Rd & north of Hwy 136, e...                  407.0
# 3  west of Delamar Mountain, north of the communi...                   30.0
# 4  Between Road 210 and Road 200 near Fine Gold C...                  274.0
#
#    incident_containment  ... incident_latitude incident_type  \
# 0                 100.0  ...         40.774000           NaN
# 1                 100.0  ...          1.000000      Wildfire
# 2                 100.0  ...         36.602575           NaN
# 3                 100.0  ...         34.288877           NaN
# 4                 100.0  ...         37.116295           NaN
#
#                             incident_id  \
# 0  2ca11d45-8139-4c16-8af0-880d99b21e82
# 1  8f61f461-552d-4538-b186-35ab030da416
# 2  094719ba-a47b-4abb-9ec5-a506b2b9fd23
# 3  58f89ff8-bd3e-4355-b1c0-8fa05c747d3f
# 4  357ffc13-bef9-48eb-810f-c5de851972eb
#
#                                         incident_url  \
# 0  https://incidents.fire.ca.gov/incidents/2017/1...
# 1  https://incidents.fire.ca.gov/incidents/2009/5...
# 2  https://incidents.fire.ca.gov/incidents/2013/2...
# 3  https://incidents.fire.ca.gov/incidents/2013/4...
# 4  https://incidents.fire.ca.gov/incidents/2013/4...
#
#   incident_date_extinguished incident_dateonly_extinguished  \
# 0       2018-01-09T13:46:00Z                         1/9/18
# 1       2009-05-25T00:00:00Z                        5/25/09
# 2       2013-02-28T20:00:00Z                        2/28/13
# 3       2013-04-22T09:00:00Z                        4/22/13
# 4       2013-05-01T07:00:00Z                         5/1/13
#
#   incident_dateonly_created is_active calfire_incident notification_desired
# 0                  10/31/17         N            False                False
# 1                   5/24/09         N             True                False
# 2                   2/24/13         N             True                False
# 3                   4/20/13         N            False                False
# 4                   4/30/13         N             True                False
#
# [5 rows x 23 columns]

# %%
wildfire_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   incident_name                     2062 non-null   object
#  1   incident_is_final                 2062 non-null   object
#  2   incident_date_last_update         2062 non-null   object
#  3   incident_date_created             2062 non-null   object
#  4   incident_administrative_unit      2050 non-null   object
#  5   incident_administrative_unit_url  0 non-null      float64
#  6   incident_county                   2052 non-null   object
#  7   incident_location                 2062 non-null   object
#  8   incident_acres_burned             2023 non-null   float64
#  9   incident_containment              2025 non-null   float64
#  10  incident_control                  123 non-null    object
#  11  incident_cooperating_agencies     1585 non-null   object
#  12  incident_longitude                2062 non-null   float64
#  13  incident_latitude                 2062 non-null   float64
#  14  incident_type                     828 non-null    object
#  15  incident_id                       2062 non-null   object
#  16  incident_url                      2062 non-null   object
#  17  incident_date_extinguished        1869 non-null   object
#  18  incident_dateonly_extinguished    1869 non-null   object
#  19  incident_dateonly_created         2062 non-null   object
#  20  is_active                         2062 non-null   object
#  21  calfire_incident                  2062 non-null   bool
#  22  notification_desired              2062 non-null   bool
# dtypes: bool(2), float64(5), object(16)
# memory usage: 342.4+ KB

# %%
wildfire_df.columns
# Out:
# Index(['incident_name', 'incident_is_final', 'incident_date_last_update',
#        'incident_date_created', 'incident_administrative_unit',
#        'incident_administrative_unit_url', 'incident_county',
#        'incident_location', 'incident_acres_burned', 'incident_containment',
#        'incident_control', 'incident_cooperating_agencies',
#        'incident_longitude', 'incident_latitude', 'incident_type',
#        'incident_id', 'incident_url', 'incident_date_extinguished',
#        'incident_dateonly_extinguished', 'incident_dateonly_created',
#        'is_active', 'calfire_incident', 'notification_desired'],
#       dtype='object')

# %%
wildfire2 = wildfire_df[['incident_name', 'incident_county', 'incident_location',
                         'incident_longitude', 'incident_latitude', 'incident_acres_burned',
                         'incident_dateonly_created', 'incident_dateonly_extinguished']]
wildfire2.head()
# Out:
#    incident_name incident_county  \
# 0    Bridge Fire          Shasta
# 1      Pala Fire       San Diego
# 2     River Fire            Inyo
# 3  Fawnskin Fire  San Bernardino
# 4      Gold Fire          Madera
#
#                                    incident_location  incident_longitude  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake          -122.309000
# 1        Hwy 76 and Pala Temecula, northwest of Pala            1.000000
# 2  south of Narrow Gauge Rd & north of Hwy 136, e...         -118.016510
# 3  west of Delamar Mountain, north of the communi...         -116.941311
# 4  Between Road 210 and Road 200 near Fine Gold C...         -119.635004
#
#    incident_latitude  incident_acres_burned incident_dateonly_created  \
# 0          40.774000                   37.0                  10/31/17
# 1           1.000000                  122.0                   5/24/09
# 2          36.602575                  407.0                   2/24/13
# 3          34.288877                   30.0                   4/20/13
# 4          37.116295                  274.0                   4/30/13
#
#   incident_dateonly_extinguished
# 0                         1/9/18
# 1                        5/25/09
# 2                        2/28/13
# 3                        4/22/13
# 4                         5/1/13

# %%
wildfire3 = wildfire2.rename(columns={'incident_name': 'incident_name', 'incident_county': 'county',
                                      'incident_location': 'location', 'incident_longitude': 'longitude', 'incident_latitude': 'latitude',
                                      'incident_acres_burned': 'acres_burned', 'incident_dateonly_created': 'start_date',
                                      'incident_dateonly_extinguished': 'extinguished_date'})
wildfire3.head()
# Out:
#    incident_name          county  \
# 0    Bridge Fire          Shasta
# 1      Pala Fire       San Diego
# 2     River Fire            Inyo
# 3  Fawnskin Fire  San Bernardino
# 4      Gold Fire          Madera
#
#                                             location   longitude   latitude  \
# 0  I-5 and Turntable Bay, 7 miles NE of Shasta Lake  -122.309000  40.774000
# 1        Hwy 76 and Pala Temecula, northwest of Pala    1.000000   1.000000
# 2  south of Narrow Gauge Rd & north of Hwy 136, e... -118.016510  36.602575
# 3  west of Delamar Mountain, north of the communi... -116.941311  34.288877
# 4  Between Road 210 and Road 200 near Fine Gold C... -119.635004  37.116295
#
#    acres_burned start_date extinguished_date
# 0          37.0   10/31/17            1/9/18
# 1         122.0    5/24/09           5/25/09
# 2         407.0    2/24/13           2/28/13
# 3          30.0    4/20/13           4/22/13
# 4         274.0    4/30/13            5/1/13

# %%
wildfire3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   incident_name      2062 non-null   object
#  1   county             2052 non-null   object
#  2   location           2062 non-null   object
#  3   longitude          2062 non-null   float64
#  4   latitude           2062 non-null   float64
#  5   acres_burned       2023 non-null   float64
#  6   start_date         2062 non-null   object
#  7   extinguished_date  1869 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 129.0+ KB

# %%
wildfire4 = wildfire3.loc[wildfire3["acres_burned"] > 1000]
wildfire4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 5 to 2050
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   incident_name      357 non-null    object
#  1   county             353 non-null    object
#  2   location           357 non-null    object
#  3   longitude          357 non-null    float64
#  4   latitude           357 non-null    float64
#  5   acres_burned       357 non-null    float64
#  6   start_date         357 non-null    object
#  7   extinguished_date  335 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 25.1+ KB

# %%
wildfire4.head()
# Out:
#       incident_name         county  \
# 5      Panther Fire         Tehama
# 8       Summit Fire      Riverside
# 13       Grand Fire  Kern, Ventura
# 22  San Felipe Fire      San Diego
# 25     General Fire      San Diego
#
#                                              location   longitude   latitude  \
# 5      140K3 Line, 8 miles northwest of Butte Meadows -121.595555  40.190062
# 8               Mias Canyon and Bluff Road in Banning -116.941311  34.288877
# 13  South of Frazier Mountain Park Rd, South of Fr... -118.941100  34.786100
# 22  San Felipe Road, north of Highway 78, East of ... -116.525790  33.121110
# 25  Banner Grade area, south of Hwy 78 & east of H... -116.520900  33.044580
#
#     acres_burned start_date extinguished_date
# 5         6896.0     5/1/13            5/9/13
# 8         2956.0     5/1/13            5/4/13
# 13        4346.0    5/15/13           5/21/13
# 22        2650.0    5/23/13           5/26/13
# 25        2500.0    5/26/13           5/31/13

# %%
wildfire4['start_date'] = pd.to_datetime(wildfire4['start_date'])
wildfire4['extinguished_date'] = pd.to_datetime(wildfire4['extinguished_date'])
wildfire4.head()
# Out:
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       incident_name         county  \
# 5      Panther Fire         Tehama
# 8       Summit Fire      Riverside
# 13       Grand Fire  Kern, Ventura
# 22  San Felipe Fire      San Diego
# 25     General Fire      San Diego
#
#                                              location   longitude   latitude  \
# 5      140K3 Line, 8 miles northwest of Butte Meadows -121.595555  40.190062
# 8               Mias Canyon and Bluff Road in Banning -116.941311  34.288877
# 13  South of Frazier Mountain Park Rd, South of Fr... -118.941100  34.786100
# 22  San Felipe Road, north of Highway 78, East of ... -116.525790  33.121110
# 25  Banner Grade area, south of Hwy 78 & east of H... -116.520900  33.044580
#
#     acres_burned start_date extinguished_date
# 5         6896.0 2013-05-01        2013-05-09
# 8         2956.0 2013-05-01        2013-05-04
# 13        4346.0 2013-05-15        2013-05-21
# 22        2650.0 2013-05-23        2013-05-26
# 25        2500.0 2013-05-26        2013-05-31

# %%
wildfire5 = wildfire4.dropna(axis=0, how='any')
wildfire5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331 entries, 5 to 2050
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   incident_name      331 non-null    object
#  1   county             331 non-null    object
#  2   location           331 non-null    object
#  3   longitude          331 non-null    float64
#  4   latitude           331 non-null    float64
#  5   acres_burned       331 non-null    float64
#  6   start_date         331 non-null    datetime64[ns]
#  7   extinguished_date  331 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(3)
# memory usage: 23.3+ KB

# %%
from datetime import datetime, timedelta
wildfire5['duration(days)'] = wildfire5['extinguished_date'] - wildfire5['start_date']
wildfire5['duration(days)'] = wildfire5['duration(days)'].dt.days
wildfire5.head()
# Out:
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       incident_name         county  \
# 5      Panther Fire         Tehama
# 8       Summit Fire      Riverside
# 13       Grand Fire  Kern, Ventura
# 22  San Felipe Fire      San Diego
# 25     General Fire      San Diego
#
#                                              location   longitude   latitude  \
# 5      140K3 Line, 8 miles northwest of Butte Meadows -121.595555  40.190062
# 8               Mias Canyon and Bluff Road in Banning -116.941311  34.288877
# 13  South of Frazier Mountain Park Rd, South of Fr... -118.941100  34.786100
# 22  San Felipe Road, north of Highway 78, East of ... -116.525790  33.121110
# 25  Banner Grade area, south of Hwy 78 & east of H... -116.520900  33.044580
#
#     acres_burned start_date extinguished_date  duration(days)
# 5         6896.0 2013-05-01        2013-05-09               8
# 8         2956.0 2013-05-01        2013-05-04               3
# 13        4346.0 2013-05-15        2013-05-21               6
# 22        2650.0 2013-05-23        2013-05-26               3
# 25        2500.0 2013-05-26        2013-05-31               5

# %%
wildfire5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331 entries, 5 to 2050
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   incident_name      331 non-null    object
#  1   county             331 non-null    object
#  2   location           331 non-null    object
#  3   longitude          331 non-null    float64
#  4   latitude           331 non-null    float64
#  5   acres_burned       331 non-null    float64
#  6   start_date         331 non-null    datetime64[ns]
#  7   extinguished_date  331 non-null    datetime64[ns]
#  8   duration(days)     331 non-null    int64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 25.9+ KB

# %%
wildfire5['ID'] = (range(1, len(wildfire5) + 1))
wildfire5['ID'] = wildfire5['ID'] + 1000
wildfire5.head()
# Out:
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       incident_name         county  \
# 5      Panther Fire         Tehama
# 8       Summit Fire      Riverside
# 13       Grand Fire  Kern, Ventura
# 22  San Felipe Fire      San Diego
# 25     General Fire      San Diego
#
#                                              location   longitude   latitude  \
# 5      140K3 Line, 8 miles northwest of Butte Meadows -121.595555  40.190062
# 8               Mias Canyon and Bluff Road in Banning -116.941311  34.288877
# 13  South of Frazier Mountain Park Rd, South of Fr... -118.941100  34.786100
# 22  San Felipe Road, north of Highway 78, East of ... -116.525790  33.121110
# 25  Banner Grade area, south of Hwy 78 & east of H... -116.520900  33.044580
#
#     acres_burned start_date extinguished_date  duration(days) month_year    ID
# 5         6896.0 2013-05-01        2013-05-09               8    2013-05  1001
# 8         2956.0 2013-05-01        2013-05-04               3    2013-05  1002
# 13        4346.0 2013-05-15        2013-05-21               6    2013-05  1003
# 22        2650.0 2013-05-23        2013-05-26               3    2013-05  1004
# 25        2500.0 2013-05-26        2013-05-31               5    2013-05  1005

# %%
wildfire5.index = wildfire5['ID']
wildfire5.head()
# Out:
#         incident_name         county  \
# ID
# 1001     Panther Fire         Tehama
# 1002      Summit Fire      Riverside
# 1003       Grand Fire  Kern, Ventura
# 1004  San Felipe Fire      San Diego
# 1005     General Fire      San Diego
#
#                                                location   longitude  \
# ID
# 1001     140K3 Line, 8 miles northwest of Butte Meadows -121.595555
# 1002              Mias Canyon and Bluff Road in Banning -116.941311
# 1003  South of Frazier Mountain Park Rd, South of Fr... -118.941100
# 1004  San Felipe Road, north of Highway 78, East of ... -116.525790
# 1005  Banner Grade area, south of Hwy 78 & east of H... -116.520900
#
#        latitude  acres_burned start_date extinguished_date  duration(days)  \
# ID
# 1001  40.190062        6896.0 2013-05-01        2013-05-09               8
# 1002  34.288877        2956.0 2013-05-01        2013-05-04               3
# 1003  34.786100        4346.0 2013-05-15        2013-05-21               6
# 1004  33.121110        2650.0 2013-05-23        2013-05-26               3
# 1005  33.044580        2500.0 2013-05-26        2013-05-31               5
#
#      month_year    ID
# ID
# 1001    2013-05  1001
# 1002    2013-05  1002
# 1003    2013-05  1003
# 1004    2013-05  1004
# 1005    2013-05  1005

# %%
wildfire6 = wildfire5.drop(['ID'], axis=1)
wildfire6.head()
# Out:
#         incident_name         county  \
# ID
# 1001     Panther Fire         Tehama
# 1002      Summit Fire      Riverside
# 1003       Grand Fire  Kern, Ventura
# 1004  San Felipe Fire      San Diego
# 1005     General Fire      San Diego
#
#                                                location   longitude  \
# ID
# 1001     140K3 Line, 8 miles northwest of Butte Meadows -121.595555
# 1002              Mias Canyon and Bluff Road in Banning -116.941311
# 1003  South of Frazier Mountain Park Rd, South of Fr... -118.941100
# 1004  San Felipe Road, north of Highway 78, East of ... -116.525790
# 1005  Banner Grade area, south of Hwy 78 & east of H... -116.520900
#
#        latitude  acres_burned start_date extinguished_date  duration(days)  \
# ID
# 1001  40.190062        6896.0 2013-05-01        2013-05-09               8
# 1002  34.288877        2956.0 2013-05-01        2013-05-04               3
# 1003  34.786100        4346.0 2013-05-15        2013-05-21               6
# 1004  33.121110        2650.0 2013-05-23        2013-05-26               3
# 1005  33.044580        2500.0 2013-05-26        2013-05-31               5
#
#      month_year
# ID
# 1001    2013-05
# 1002    2013-05
# 1003    2013-05
# 1004    2013-05
# 1005    2013-05

# %%
wildfire6.to_csv("Resources/ca_wildfire.csv", index=True)

# %%
wildfire5['month_year'] = wildfire5['start_date'].dt.strftime('%Y-%m')
wildfire5.head()
# Out:
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       incident_name         county  \
# 5      Panther Fire         Tehama
# 8       Summit Fire      Riverside
# 13       Grand Fire  Kern, Ventura
# 22  San Felipe Fire      San Diego
# 25     General Fire      San Diego
#
#                                              location   longitude   latitude  \
# 5      140K3 Line, 8 miles northwest of Butte Meadows -121.595555  40.190062
# 8               Mias Canyon and Bluff Road in Banning -116.941311  34.288877
# 13  South of Frazier Mountain Park Rd, South of Fr... -118.941100  34.786100
# 22  San Felipe Road, north of Highway 78, East of ... -116.525790  33.121110
# 25  Banner Grade area, south of Hwy 78 & east of H... -116.520900  33.044580
#
#     acres_burned start_date extinguished_date  duration(days) month_year
# 5         6896.0 2013-05-01        2013-05-09               8    2013-05
# 8         2956.0 2013-05-01        2013-05-04               3    2013-05
# 13        4346.0 2013-05-15        2013-05-21               6    2013-05
# 22        2650.0 2013-05-23        2013-05-26               3    2013-05
# 25        2500.0 2013-05-26        2013-05-31               5    2013-05

# %%
wildfire6 = wildfire5.groupby(["month_year"]).sum()
wildfire6.tail()
# Out:
#              longitude    latitude  acres_burned  duration(days)
# month_year
# 2022-05    -114.484173   34.010838        5856.0              13
# 2022-06    -118.889446   34.936618        2500.0               5
# 2022-07    -119.614000   37.499000        4886.0              28
# 2022-08    -118.647900   34.525500        5208.0               6
# 2022-09    -480.303120  156.484380       87645.0             129

# %%
drought_data = pd.read_csv("Resources/USDM-california.csv")
drought_df = pd.DataFrame(drought_data)
drought_df.head()
# Out:
#     MapDate StateAbbreviation   None     D0     D1     D2   D3   D4  \
# 0  20230404                CA  56.17  43.83  24.86   0.82  0.0  0.0
# 1  20230328                CA  55.34  44.66  28.11   1.95  0.0  0.0
# 2  20230321                CA  48.51  51.49  35.88   8.49  0.0  0.0
# 3  20230314                CA  44.66  55.34  36.42   8.49  0.0  0.0
# 4  20230307                CA  26.84  73.16  43.06  19.00  0.0  0.0
#
#   ValidStart ValidEnd  StatisticFormatID
# 0     4/4/23  4/10/23                  1
# 1    3/28/23   4/3/23                  1
# 2    3/21/23  3/27/23                  1
# 3    3/14/23  3/20/23                  1
# 4     3/7/23  3/13/23                  1

# %%
drought1 = drought_df[["None", "D0", "D1", "D2", "D3", "D4", "ValidStart"]]

# %%
drought1["D3_percent"] = drought1["D3"] - drought1["D4"]
drought1["D2_percent"] = drought1["D2"] - drought1["D3_percent"]
drought1["D1_percent"] = drought1["D1"] - drought1["D2_percent"]
drought1["D0_percent"] = drought1["D0"] - drought1["D1_percent"]
drought1.head(10)
# Out:
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/leahapking/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     None     D0     D1     D2   D3   D4 ValidStart  D3_percent  D2_percent  \
# 0  56.17  43.83  24.86   0.82  0.0  0.0     4/4/23         0.0        0.82
# 1  55.34  44.66  28.11   1.95  0.0  0.0    3/28/23         0.0        1.95
# 2  48.51  51.49  35.88   8.49  0.0  0.0    3/21/23         0.0        8.49
# 3  44.66  55.34  36.42   8.49  0.0  0.0    3/14/23         0.0        8.49
# 4  26.84  73.16  43.06  19.00  0.0  0.0     3/7/23         0.0       19.00
# 5  16.71  83.29  49.13  24.96  0.0  0.0    2/28/23         0.0       24.96
# 6   0.61  99.39  84.60  32.62  0.0  0.0    2/21/23         0.0       32.62
# 7   0.64  99.36  84.60  32.62  0.0  0.0    2/14/23         0.0       32.62
# 8   0.64  99.36  84.60  32.62  0.0  0.0     2/7/23         0.0       32.62
# 9   0.64  99.36  89.56  32.57  0.0  0.0    1/31/23         0.0       32.57
#
#    D1_percent  D0_percent
# 0       24.04       19.79
# 1       26.16       18.50
# 2       27.39       24.10
# 3       27.93       27.41
# 4       24.06       49.10
# 5       24.17       59.12
# 6       51.98       47.41
# 7       51.98       47.38
# 8       51.98       47.38
# 9       56.99       42.37

# %%
drought2 = drought1[["None", "D0_percent", "D1_percent", "D2_percent", "D3_percent", "D4", "ValidStart"]]
drought3 = drought2.rename(columns={'None':'None', 'D0_percent':'D0_percent', 'D1_percent':'D1_percent', 'D2_percent':'D2_percent', 'D3_percent':'D3_percent', 'D4':'D4_percent', 'ValidStart':'start_date'})
drought3.head()
# Out:
#     None  D0_percent  D1_percent  D2_percent  D3_percent  D4_percent  \
# 0  56.17       19.79       24.04        0.82         0.0         0.0
# 1  55.34       18.50       26.16        1.95         0.0         0.0
# 2  48.51       24.10       27.39        8.49         0.0         0.0
# 3  44.66       27.41       27.93        8.49         0.0         0.0
# 4  26.84       49.10       24.06       19.00         0.0         0.0
#
#   start_date
# 0     4/4/23
# 1    3/28/23
# 2    3/21/23
# 3    3/14/23
# 4     3/7/23

# %%
drought3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214 entries, 0 to 1213
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   None        1214 non-null   float64
#  1   D0_percent  1214 non-null   float64
#  2   D1_percent  1214 non-null   float64
#  3   D2_percent  1214 non-null   float64
#  4   D3_percent  1214 non-null   float64
#  5   D4_percent  1214 non-null   float64
#  6   start_date  1214 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 66.5+ KB

# %%
drought3['start_date'] = pd.to_datetime(drought3['start_date'])
drought3['date'] = drought3['start_date'] + timedelta(days=3)
drought3.head()
# Out:
#     None  D0_percent  D1_percent  D2_percent  D3_percent  D4_percent  \
# 0  56.17       19.79       24.04        0.82         0.0         0.0
# 1  55.34       18.50       26.16        1.95         0.0         0.0
# 2  48.51       24.10       27.39        8.49         0.0         0.0
# 3  44.66       27.41       27.93        8.49         0.0         0.0
# 4  26.84       49.10       24.06       19.00         0.0         0.0
#
#   start_date       date
# 0 2023-04-04 2023-04-07
# 1 2023-03-28 2023-03-31
# 2 2023-03-21 2023-03-24
# 3 2023-03-14 2023-03-17
# 4 2023-03-07 2023-03-10

# %%
drought3['month_year'] = drought3['start_date'].dt.strftime('%Y-%m')

# %%
avg_drought = drought3.groupby(["month_year"]).mean()
avg_drought.head()
# Out:
#                 None  D0_percent  D1_percent  D2_percent  D3_percent  \
# month_year
# 2000-01      35.5175     64.4825      0.0000         0.0         0.0
# 2000-02      65.2620     34.7280      0.0100         0.0         0.0
# 2000-03      95.6850      4.3075      0.0075         0.0         0.0
# 2000-04      97.4925      2.5075      0.0000         0.0         0.0
# 2000-05     100.0000      0.0000      0.0000         0.0         0.0
#
#             D4_percent
# month_year
# 2000-01            0.0
# 2000-02            0.0
# 2000-03            0.0
# 2000-04            0.0
# 2000-05            0.0

# %%
merge_data = pd.merge(avg_drought, wildfire6, on='month_year', how='left')
merge_data1 = pd.DataFrame(merge_data)
merge_data1.head(10)
# Out:
#                 None  D0_percent  D1_percent  D2_percent  D3_percent  \
# month_year
# 2000-01      35.5175     64.4825      0.0000         0.0         0.0
# 2000-02      65.2620     34.7280      0.0100         0.0         0.0
# 2000-03      95.6850      4.3075      0.0075         0.0         0.0
# 2000-04      97.4925      2.5075      0.0000         0.0         0.0
# 2000-05     100.0000      0.0000      0.0000         0.0         0.0
# 2000-06     100.0000      0.0000      0.0000         0.0         0.0
# 2000-07      98.0975      1.9025      0.0000         0.0         0.0
# 2000-08      81.5520     17.9060      0.5420         0.0         0.0
# 2000-09      87.6900     12.3100      0.0000         0.0         0.0
# 2000-10      89.3660     10.6340      0.0000         0.0         0.0
#
#             D4_percent  longitude  latitude  acres_burned  duration(days)
# month_year
# 2000-01            0.0        NaN       NaN           NaN             NaN
# 2000-02            0.0        NaN       NaN           NaN             NaN
# 2000-03            0.0        NaN       NaN           NaN             NaN
# 2000-04            0.0        NaN       NaN           NaN             NaN
# 2000-05            0.0        NaN       NaN           NaN             NaN
# 2000-06            0.0        NaN       NaN           NaN             NaN
# 2000-07            0.0        NaN       NaN           NaN             NaN
# 2000-08            0.0        NaN       NaN           NaN             NaN
# 2000-09            0.0        NaN       NaN           NaN             NaN
# 2000-10            0.0        NaN       NaN           NaN             NaN

# %%
merge_data2 = merge_data1.drop(merge_data1.index[range(160)])
merge_data3 = merge_data2.drop(merge_data2.index[[-1,-2,-3,-4,-5,-6,-7]])
merge_data3.tail()
# Out:
#             None  D0_percent  D1_percent  D2_percent  D3_percent  D4_percent  \
# month_year
# 2022-05      0.0     44.9500     55.0500     44.8380     51.2780      4.6720
# 2022-06      0.0     49.4700     50.5300     49.2600     48.2200     11.5900
# 2022-07      0.0     50.3275     49.6725     50.1175     47.3575     12.4525
# 2022-08      0.0     66.9960     33.0040     66.7620     30.7520     15.6720
# 2022-09      0.0     70.9950     29.0050     70.7550     24.1575     16.5700
#
#              longitude    latitude  acres_burned  duration(days)
# month_year
# 2022-05    -114.484173   34.010838        5856.0            13.0
# 2022-06    -118.889446   34.936618        2500.0             5.0
# 2022-07    -119.614000   37.499000        4886.0            28.0
# 2022-08    -118.647900   34.525500        5208.0             6.0
# 2022-09    -480.303120  156.484380       87645.0           129.0

# %%
merge_data4 = merge_data3[['None', 'D0_percent', 'D1_percent', 'D2_percent', 'D3_percent',
       'D4_percent', 'acres_burned']]

# %%
#rename: average drought & total acres burned
merge_data5 = merge_data4.rename(columns={'None':'none_avg_pct', 'D0_percent':'D0_avg_pct', 'D1_percent':'D1_avg_pct',
                                          'D2_percent':'D2_avg_pct', 'D3_percent':'D3_avg_pct', 'D4_percent':'D4_avg_pct',
                                          'acres_burned': 'total_acres_burned'})
merge_data5.head()
# Out:
#             none_avg_pct  D0_avg_pct  D1_avg_pct  D2_avg_pct  D3_avg_pct  \
# month_year
# 2013-05            0.000      48.090      51.910      46.250        0.00
# 2013-06            0.000      68.530      31.470      66.715        0.00
# 2013-07            0.000      95.206       4.794      93.436        0.00
# 2013-08            0.000      87.110      12.890      85.340        8.52
# 2013-09            1.315      82.155      16.530      80.030       11.36
#
#             D4_avg_pct  total_acres_burned
# month_year
# 2013-05            0.0             51606.0
# 2013-06            0.0              1708.0
# 2013-07            0.0             72332.0
# 2013-08            0.0            335755.0
# 2013-09            0.0             11184.0

# %%
merge_data5['ID'] = (range(1, len(merge_data5) + 1))
merge_data5['ID'] = merge_data5['ID'] + 100
merge_data5.head()
# Out:
#             none_avg_pct  D0_avg_pct  D1_avg_pct  D2_avg_pct  D3_avg_pct  \
# month_year
# 2013-05            0.000      48.090      51.910      46.250        0.00
# 2013-06            0.000      68.530      31.470      66.715        0.00
# 2013-07            0.000      95.206       4.794      93.436        0.00
# 2013-08            0.000      87.110      12.890      85.340        8.52
# 2013-09            1.315      82.155      16.530      80.030       11.36
#
#             D4_avg_pct  total_acres_burned   ID
# month_year
# 2013-05            0.0             51606.0  101
# 2013-06            0.0              1708.0  102
# 2013-07            0.0             72332.0  103
# 2013-08            0.0            335755.0  104
# 2013-09            0.0             11184.0  105

# %%
merge_data5.index = merge_data5['ID']
merge_data5.head()
# Out:
#      none_avg_pct  D0_avg_pct  D1_avg_pct  D2_avg_pct  D3_avg_pct  D4_avg_pct  \
# ID
# 101         0.000      48.090      51.910      46.250        0.00         0.0
# 102         0.000      68.530      31.470      66.715        0.00         0.0
# 103         0.000      95.206       4.794      93.436        0.00         0.0
# 104         0.000      87.110      12.890      85.340        8.52         0.0
# 105         1.315      82.155      16.530      80.030       11.36         0.0
#
#      total_acres_burned   ID
# ID
# 101             51606.0  101
# 102              1708.0  102
# 103             72332.0  103
# 104            335755.0  104
# 105             11184.0  105

# %%
merge_data6 = merge_data5.drop(['ID'], axis=1)
merge_data6.head()
# Out:
#      none_avg_pct  D0_avg_pct  D1_avg_pct  D2_avg_pct  D3_avg_pct  D4_avg_pct  \
# ID
# 101         0.000      48.090      51.910      46.250        0.00         0.0
# 102         0.000      68.530      31.470      66.715        0.00         0.0
# 103         0.000      95.206       4.794      93.436        0.00         0.0
# 104         0.000      87.110      12.890      85.340        8.52         0.0
# 105         1.315      82.155      16.530      80.030       11.36         0.0
#
#      total_acres_burned
# ID
# 101             51606.0
# 102              1708.0
# 103             72332.0
# 104            335755.0
# 105             11184.0

# %%
merge_data6.to_csv("Resources/ca_drought.csv", index=True)
